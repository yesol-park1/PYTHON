# %% [markdown]
# <a href="https://colab.research.google.com/github/yesol-park1/PYTHON/blob/main/10%EC%A3%BC%EC%B0%A8%20%EC%88%99%EC%A0%9C_2026173655_%EB%B0%95%EC%98%88%EC%86%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10주차 과제: 클래스 II
#
# 강의교안 p.11~p.31의 코드를 따라 작성하고 실행한 결과입니다.
#
# ## 실습 내용
# - 전역변수를 활용한 계산기
# - 여러 개의 계산기 함수
# - Calculator 클래스
# - 클래스 변수
# - 메서드
# - 객체 변수
# - __init__
# - FourCal 사칙연산 클래스
# - 주사위 게임 순차적 프로그래밍
# - 주사위 게임 OOP 방식

# %%
# p.11 계산기 더하기 기능

result = 0

def adder(num):
    global result
    result += num
    return result

print(adder(3))
print(adder(4))
print(adder(5))
# Out:
# 3
# 7
# 12

# %%
# p.12 만약 계산기가 두 개 필요하다면?

result1 = 0
result2 = 0

def adder1(num):
    global result1
    result1 += num
    return result1

def adder2(num):
    global result2
    result2 += num
    return result2

print(adder1(3))
print(adder1(4))
print(adder2(3))
print(adder2(7))
# Out:
# 3
# 7
# 3
# 10

# %%
# p.13 계산기가 여러 개 필요하다면? - 클래스 사용

class Calculator:
    def __init__(self):
        self.result = 0

    def adder(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.adder(3))
print(cal1.adder(4))
print(cal2.adder(3))
print(cal2.adder(7))
# Out:
# 3
# 7
# 3
# 10

# %%
# p.15 클래스 변수

class Service:
    secret = "지구는 4006년에 멸망한다."

an = Service()

print(an.secret)
# Out:
# 지구는 4006년에 멸망한다.

# %%
# p.15 클래스 변수

class Service:
    secret = "지구는 4006년에 멸망한다."

an = Service()

print(an.secret)
# Out:
# 지구는 4006년에 멸망한다.

# %%
# p.17 클래스 내부의 함수, 메서드

class Service:
    secret = "지구는 4006년에 멸망한다."

    def sum(self, a, b):
        result = a + b
        print("%s + %s = %s이다." % (a, b, result))

an = Service()
an.sum(1, 1)
# Out:
# 1 + 1 = 2이다.

# %%
# p.17 클래스 내부의 함수, 메서드

class Service:
    secret = "지구는 4006년에 멸망한다."

    def sum(self, a, b):
        result = a + b
        print("%s + %s = %s이다." % (a, b, result))

an = Service()
an.sum(1, 1)
# Out:
# 1 + 1 = 2이다.

# %%
# p.19 객체 변수

class Service:
    secret = "지구는 4006년에 멸망한다."

    def setname(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service()
an.setname("박달수")
an.sum(1, 1)
# Out:
# 박달수님, 1 + 1 = 2입니다.

# %%
# p.21 setname을 호출하지 않는 경우 발생하는 문제

class Service:
    secret = "지구는 4006년에 멸망한다."

    def setname(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

lee = Service()

try:
    lee.sum(1, 1)
except AttributeError as e:
    print("오류 발생:", e)
# Out:
# 오류 발생: 'Service' object has no attribute 'name'

# %%
# p.22 __init__

class Service:
    secret = "지구는 4006년에 멸망한다."

    def __init__(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service("박달수")
an.sum(1, 1)
# Out:
# 박달수님, 1 + 1 = 2입니다.

# %%
# p.24 사칙연산 클래스 - 껍데기 클래스

class FourCal:
    pass

a = FourCal()

print(type(a))
# Out:
# <class '__main__.FourCal'>

# %%
# p.25 사칙연산 클래스 - 데이터 세팅

class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

a = FourCal()
a.setdata(4, 2)

print(a.first)
print(a.second)
# Out:
# 4
# 2

# %%
# p.26 사칙연산 클래스 - 더하기

class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        result = self.first + self.second
        return result

a = FourCal()
a.setdata(4, 2)

print(a.sum())
# Out:
# 6

# %%
# p.27 사칙연산 클래스 전체

class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        result = self.first + self.second
        return result

    def mul(self):
        result = self.first * self.second
        return result

    def sub(self):
        result = self.first - self.second
        return result

    def div(self):
        result = self.first / self.second
        return result

a = FourCal()
b = FourCal()

a.setdata(4, 2)
b.setdata(3, 7)

print(a.sum())
print(a.mul())
print(a.sub())
print(a.div())
print(b.sub())
# Out:
# 6
# 8
# 2
# 2.0
# -4

# %%
# p.30 간단한 주사위 게임 - 순차적 프로그래밍

import random

player1_dice = []
player2_dice = []

for i in range(3):
    player1_dice.append(random.randint(1, 6))
    player2_dice.append(random.randint(1, 6))

print("Player 1 rolled " + str(player1_dice))
print("Player 2 rolled " + str(player2_dice))

if sum(player1_dice) == sum(player2_dice):
    print("Draw")
elif sum(player1_dice) > sum(player2_dice):
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Player 1 rolled [5, 2, 3]
# Player 2 rolled [3, 6, 3]
# Player 2 wins

# %%
# p.31 간단한 주사위 게임 - OOP

from random import randint

class Player:
    def __init__(self):
        self.dice = []

    def roll(self):
        self.dice = []  # clear current dice
        for i in range(3):
            self.dice.append(randint(1, 6))

    def get_dice(self):
        return self.dice

player1 = Player()
player2 = Player()

player1.roll()
player2.roll()

print("Player 1 rolled " + str(player1.get_dice()))
print("Player 2 rolled " + str(player2.get_dice()))

if sum(player1.get_dice()) == sum(player2.get_dice()):
    print("Draw")
elif sum(player1.get_dice()) > sum(player2.get_dice()):
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Player 1 rolled [2, 6, 6]
# Player 2 rolled [2, 1, 3]
# Player 1 wins
